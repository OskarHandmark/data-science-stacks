# %%
import json
import pandas as pd
import seaborn as sns
sns.set(style='white', font_scale=1.5, rc={'figure.figsize':(14,7)})

f  = json.load(open('data/elevation.json', 'r'))
df = pd.DataFrame(f)

# %%
df.head()
# Out:
#    elevation
# 0  20.458851
# 1  23.298998
# 2  25.089777
# 3  20.792149
# 4  18.355030

# %%
sns.lineplot(data=df)
sns.despine(left=True, bottom=True)
